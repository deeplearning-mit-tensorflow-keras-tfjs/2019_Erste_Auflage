# %%
import conx as cx
net = cx.Network.get("vgg19")
img = cx.download("https://upload.wikimedia.org/wikipedia/commons/thumb/5/5d/Ferrari_500_fr.jpg/800px-Ferrari_500_fr.jpg", filename="ferrari_500.jpg")
# Out:
# Using TensorFlow backend.
# ConX, version 3.7.5
# A local file was found, but it seems to be incomplete or outdated because the auto file hash does not match the original value of 253f8cb515780f3b799900260a226db6 so we will re-download the data.
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.1/vgg19_weights_tf_dim_ordering_tf_kernels.h5
# 574717952/574710816 [==============================] - 395s 1us/step
# Using cached https://upload.wikimedia.org/wikipedia/commons/thumb/5/5d/Ferrari_500_fr.jpg/800px-Ferrari_500_fr.jpg as './ferrari_500.jpg'.
# WARNING: no such history file '/Users/matthieuderu/.keras/models/history.pickle'

# %%
img = cx.image("ferrari_500.jpg", resize=(224, 224))

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x119620BA8>

# %%
output = net.propagate(net.preprocess(cx.image_to_array(img)))
predictions = net.postprocess(output)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0a16f593cea6> in <module>()
# ----> 1 output = net.propagate(net.preprocess(cx.image_to_array(img)))
#       2 predictions = net.postprocess(output)
#
# NameError: name 'net' is not defined

# %%
net.picture(net.preprocess(cx.image_to_array(img)), scale=0.2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7729e52a18c1> in <module>()
# ----> 1 net.picture(net.preprocess(cx.image_to_array(img)), scale=0.2)
#
# NameError: name 'net' is not defined
